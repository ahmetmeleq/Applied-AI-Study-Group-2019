# %% [markdown]
# # TabNet: Attentive Interpretable Tabular Learning

# %% [markdown]
# ## Preparation

# %%
# %%capture
# !pip install pytorch-tabnet
# !pip install imblearn
# !pip install catboost
# !pip install tab-transformer-pytorch

# %%
import torch
import torch.nn as nn
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, accuracy_score, f1_score, confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import plot_confusion_matrix

from imblearn.metrics import sensitivity_score,specificity_score,sensitivity_specificity_support

import pandas as pd
import numpy as np
import pprint

from catboost import CatBoostClassifier

import matplotlib.pyplot as plt

from pytorch_tabnet.tab_model import TabNetClassifier
from tab_transformer_pytorch import TabTransformer;
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# Cover type dataset contains tree observations from four areas of the Roosevelt National Forest in Colorado. All observations are cartographic variables (no remote sensing) from 30 meter x 30 meter sections of forest. There are over half a million measurements total! This dataset includes information on tree type, shadow coverage, distance to nearby landmarks (roads etcetera), soil type, and local topography.
#
# Class descriptions:
#
# * **1:** Spruce/Fir
# * **2:** Lodgepole Pine
# * **3:** Ponderosa Pine
# * **4:** Cottonwood/Willow
# * **5:** Aspen
# * **6:** Douglas-fir
# * **7:** Krummholz
#
# For more details for dataset, please see metadata from [this link](https://archive.ics.uci.edu/ml/machine-learning-databases/covtype/).

# %%
base_data_path = "/content/drive/MyDrive/applied_ai_enes_safak/datasets/"
forest_cover_type_dataset = base_data_path + "cover_type.csv"

data = pd.read_csv(forest_cover_type_dataset)

# %%
df_train = data.iloc[:11_340,:]
df_val = data.iloc[11_340:11_340+3_780,:]
df_test = data.iloc[11_340+3_780:, :]

# %%
print(len(df_train),len(df_val),len(df_test))
# Out:
# 11340 3780 565892

# %%
pprint.saferepr(data.columns.to_list())
# Out:
# "['Elevation', 'Aspect', 'Slope', 'Horizontal_Distance_To_Hydrology', 'Vertical_Distance_To_Hydrology', 'Horizontal_Distance_To_Roadways', 'Hillshade_9am', 'Hillshade_Noon', 'Hillshade_3pm', 'Horizontal_Distance_To_Fire_Points', 'Wilderness_Area1', 'Wilderness_Area2', 'Wilderness_Area3', 'Wilderness_Area4', 'Soil_Type1', 'Soil_Type2', 'Soil_Type3', 'Soil_Type4', 'Soil_Type5', 'Soil_Type6', 'Soil_Type7', 'Soil_Type8', 'Soil_Type9', 'Soil_Type10', 'Soil_Type11', 'Soil_Type12', 'Soil_Type13', 'Soil_Type14', 'Soil_Type15', 'Soil_Type16', 'Soil_Type17', 'Soil_Type18', 'Soil_Type19', 'Soil_Type20', 'Soil_Type21', 'Soil_Type22', 'Soil_Type23', 'Soil_Type24', 'Soil_Type25', 'Soil_Type26', 'Soil_Type27', 'Soil_Type28', 'Soil_Type29', 'Soil_Type30', 'Soil_Type31', 'Soil_Type32', 'Soil_Type33', 'Soil_Type34', 'Soil_Type35', 'Soil_Type36', 'Soil_Type37', 'Soil_Type38', 'Soil_Type39', 'Soil_Type40', 'Cover_Type']"

# %%
data['Cover_Type'].value_counts()
# Out:
# 2    283301
# 1    211840
# 3     35754
# 7     20510
# 6     17367
# 5      9493
# 4      2747
# Name: Cover_Type, dtype: int64

# %%
X_train, y_train = df_train.iloc[:,:-1].values, df_train.iloc[:,-1].values
X_val, y_val = df_val.iloc[:,:-1].values, df_val.iloc[:,-1].values
X_test, y_test = df_test.iloc[:,:-1].values, df_test.iloc[:,-1].values

# %% [markdown]
# ## Modeling TabNet

# %%
from pytorch_tabnet.metrics import Metric
class GMean(Metric):
  def __init__(self):
    self._name = "gmean"
    self._maximize = True
  
  def __call__(self, y_true, y_pred):
    return np.sqrt(sensitivity_score(y_true, y_pred, average="macro"), specificity_score(y_true, y_pred, average="macro"))

# %%
clf = TabNetClassifier(
    lambda_sparse = 1e-4,
    n_d = 64,
    n_a = 64,
    gamma = 1.5,
    optimizer_params=dict(lr=0.02),
    scheduler_params={"gamma":0.95, "verbose":0, "step_size":15},
    #scheduler_fn = torch.optim.lr_scheduler.ExponentialLR,
    scheduler_fn = torch.optim.lr_scheduler.StepLR,
    #optimizer_fn = torch.optim.AdamW
    optimizer_fn = torch.optim.Adam,
)
# Out:
# Device used : cuda

# %%
clf.fit(
    X_train = X_train,
    y_train = y_train,
    eval_set = [(X_val, y_val)],
    max_epochs = 1000,
    batch_size = 1024,
    virtual_batch_size = 128,
    num_workers = 0,
    patience = 20,
    drop_last = False,
    eval_metric=['balanced_accuracy']
)

# more for batching strategies: https://arxiv.org/pdf/1906.03548.pdf
# Out:
# epoch 0  | loss: 1.68201 | val_0_balanced_accuracy: 0.13069 |  0:00:00s
# epoch 1  | loss: 0.99313 | val_0_balanced_accuracy: 0.13571 |  0:00:00s
# epoch 2  | loss: 0.8866  | val_0_balanced_accuracy: 0.14233 |  0:00:01s
# epoch 3  | loss: 0.84699 | val_0_balanced_accuracy: 0.14286 |  0:00:01s
# epoch 4  | loss: 0.80639 | val_0_balanced_accuracy: 0.14286 |  0:00:02s
# epoch 5  | loss: 0.77342 | val_0_balanced_accuracy: 0.14153 |  0:00:02s
# epoch 6  | loss: 0.78371 | val_0_balanced_accuracy: 0.14392 |  0:00:03s
# epoch 7  | loss: 0.77851 | val_0_balanced_accuracy: 0.14418 |  0:00:03s
# epoch 8  | loss: 0.75601 | val_0_balanced_accuracy: 0.14365 |  0:00:04s
# epoch 9  | loss: 0.72842 | val_0_balanced_accuracy: 0.14683 |  0:00:04s
# epoch 10 | loss: 0.73169 | val_0_balanced_accuracy: 0.15582 |  0:00:05s
# epoch 11 | loss: 0.735   | val_0_balanced_accuracy: 0.17328 |  0:00:05s
# epoch 12 | loss: 0.71831 | val_0_balanced_accuracy: 0.18624 |  0:00:06s
# epoch 13 | loss: 0.69209 | val_0_balanced_accuracy: 0.19471 |  0:00:06s
# epoch 14 | loss: 0.68402 | val_0_balanced_accuracy: 0.21772 |  0:00:07s
# epoch 15 | loss: 0.68417 | val_0_balanced_accuracy: 0.2463  |  0:00:07s
# epoch 16 | loss: 0.6762  | val_0_balanced_accuracy: 0.29524 |  0:00:08s
# epoch 17 | loss: 0.68102 | val_0_balanced_accuracy: 0.32275 |  0:00:08s
# epoch 18 | loss: 0.68554 | val_0_balanced_accuracy: 0.34815 |  0:00:09s
# epoch 19 | loss: 0.72982 | val_0_balanced_accuracy: 0.40661 |  0:00:09s
# epoch 20 | loss: 0.72193 | val_0_balanced_accuracy: 0.43439 |  0:00:10s
# epoch 21 | loss: 0.71965 | val_0_balanced_accuracy: 0.43889 |  0:00:10s
# epoch 22 | loss: 0.7106  | val_0_balanced_accuracy: 0.46905 |  0:00:11s
# epoch 23 | loss: 0.6845  | val_0_balanced_accuracy: 0.52196 |  0:00:11s
# epoch 24 | loss: 0.66415 | val_0_balanced_accuracy: 0.57646 |  0:00:12s
# epoch 25 | loss: 0.67065 | val_0_balanced_accuracy: 0.58413 |  0:00:12s
# epoch 26 | loss: 0.68276 | val_0_balanced_accuracy: 0.59921 |  0:00:12s
# epoch 27 | loss: 0.66984 | val_0_balanced_accuracy: 0.59233 |  0:00:13s
# epoch 28 | loss: 0.70939 | val_0_balanced_accuracy: 0.57751 |  0:00:13s
# epoch 29 | loss: 0.67931 | val_0_balanced_accuracy: 0.65423 |  0:00:14s
# epoch 30 | loss: 0.65992 | val_0_balanced_accuracy: 0.69921 |  0:00:14s
# epoch 31 | loss: 0.63203 | val_0_balanced_accuracy: 0.72222 |  0:00:15s
# epoch 32 | loss: 0.62553 | val_0_balanced_accuracy: 0.72196 |  0:00:15s
# epoch 33 | loss: 0.62926 | val_0_balanced_accuracy: 0.71323 |  0:00:16s
# epoch 34 | loss: 0.60912 | val_0_balanced_accuracy: 0.72328 |  0:00:16s
# epoch 35 | loss: 0.608   | val_0_balanced_accuracy: 0.74101 |  0:00:17s
# epoch 36 | loss: 0.59863 | val_0_balanced_accuracy: 0.74365 |  0:00:17s
# epoch 37 | loss: 0.59361 | val_0_balanced_accuracy: 0.75423 |  0:00:18s
# epoch 38 | loss: 0.59534 | val_0_balanced_accuracy: 0.75132 |  0:00:18s
# epoch 39 | loss: 0.56963 | val_0_balanced_accuracy: 0.76349 |  0:00:19s
# epoch 40 | loss: 0.56838 | val_0_balanced_accuracy: 0.74444 |  0:00:19s
# epoch 41 | loss: 0.56418 | val_0_balanced_accuracy: 0.76296 |  0:00:20s
# epoch 42 | loss: 0.55416 | val_0_balanced_accuracy: 0.72328 |  0:00:20s
# epoch 43 | loss: 0.58945 | val_0_balanced_accuracy: 0.75238 |  0:00:21s
# epoch 44 | loss: 0.57961 | val_0_balanced_accuracy: 0.75582 |  0:00:21s
# epoch 45 | loss: 0.56103 | val_0_balanced_accuracy: 0.7664  |  0:00:22s
# epoch 46 | loss: 0.54254 | val_0_balanced_accuracy: 0.7619  |  0:00:22s
# epoch 47 | loss: 0.5425  | val_0_balanced_accuracy: 0.75979 |  0:00:23s
# epoch 48 | loss: 0.53719 | val_0_balanced_accuracy: 0.74392 |  0:00:23s
# epoch 49 | loss: 0.54797 | val_0_balanced_accuracy: 0.73466 |  0:00:24s
# epoch 50 | loss: 0.53452 | val_0_balanced_accuracy: 0.76481 |  0:00:24s
# epoch 51 | loss: 0.51553 | val_0_balanced_accuracy: 0.7664  |  0:00:25s
# epoch 52 | loss: 0.54553 | val_0_balanced_accuracy: 0.76825 |  0:00:25s
# epoch 53 | loss: 0.55253 | val_0_balanced_accuracy: 0.75873 |  0:00:26s
# epoch 54 | loss: 0.54628 | val_0_balanced_accuracy: 0.76138 |  0:00:26s
# epoch 55 | loss: 0.54858 | val_0_balanced_accuracy: 0.73915 |  0:00:27s
# epoch 56 | loss: 0.54065 | val_0_balanced_accuracy: 0.76772 |  0:00:27s
# epoch 57 | loss: 0.53102 | val_0_balanced_accuracy: 0.77646 |  0:00:28s
# epoch 58 | loss: 0.50756 | val_0_balanced_accuracy: 0.78413 |  0:00:28s
# epoch 59 | loss: 0.51009 | val_0_balanced_accuracy: 0.77857 |  0:00:29s
# epoch 60 | loss: 0.49102 | val_0_balanced_accuracy: 0.77037 |  0:00:29s
# epoch 61 | loss: 0.50618 | val_0_balanced_accuracy: 0.78333 |  0:00:30s
# epoch 62 | loss: 0.50544 | val_0_balanced_accuracy: 0.77487 |  0:00:30s
# epoch 63 | loss: 0.48134 | val_0_balanced_accuracy: 0.78704 |  0:00:31s
# epoch 64 | loss: 0.49796 | val_0_balanced_accuracy: 0.77275 |  0:00:31s
# epoch 65 | loss: 0.49983 | val_0_balanced_accuracy: 0.78148 |  0:00:32s
# epoch 66 | loss: 0.49273 | val_0_balanced_accuracy: 0.77804 |  0:00:32s
# epoch 67 | loss: 0.49521 | val_0_balanced_accuracy: 0.78757 |  0:00:32s
# epoch 68 | loss: 0.47391 | val_0_balanced_accuracy: 0.79048 |  0:00:33s
# epoch 69 | loss: 0.47502 | val_0_balanced_accuracy: 0.80132 |  0:00:33s
# epoch 70 | loss: 0.46229 | val_0_balanced_accuracy: 0.80185 |  0:00:34s
# epoch 71 | loss: 0.45139 | val_0_balanced_accuracy: 0.79153 |  0:00:34s
# epoch 72 | loss: 0.49118 | val_0_balanced_accuracy: 0.77566 |  0:00:35s
# epoch 73 | loss: 0.50012 | val_0_balanced_accuracy: 0.77884 |  0:00:35s
# epoch 74 | loss: 0.46156 | val_0_balanced_accuracy: 0.78915 |  0:00:36s
# epoch 75 | loss: 0.4524  | val_0_balanced_accuracy: 0.79259 |  0:00:36s
# epoch 76 | loss: 0.43788 | val_0_balanced_accuracy: 0.79683 |  0:00:37s
# epoch 77 | loss: 0.4525  | val_0_balanced_accuracy: 0.79762 |  0:00:37s
# epoch 78 | loss: 0.45131 | val_0_balanced_accuracy: 0.79048 |  0:00:38s
# epoch 79 | loss: 0.44784 | val_0_balanced_accuracy: 0.79418 |  0:00:38s
# epoch 80 | loss: 0.45106 | val_0_balanced_accuracy: 0.79894 |  0:00:39s
# epoch 81 | loss: 0.43353 | val_0_balanced_accuracy: 0.80079 |  0:00:39s
# epoch 82 | loss: 0.41755 | val_0_balanced_accuracy: 0.80979 |  0:00:40s
# epoch 83 | loss: 0.41396 | val_0_balanced_accuracy: 0.81243 |  0:00:40s
# epoch 84 | loss: 0.43932 | val_0_balanced_accuracy: 0.79233 |  0:00:41s
# epoch 85 | loss: 0.44928 | val_0_balanced_accuracy: 0.79497 |  0:00:41s
# epoch 86 | loss: 0.48436 | val_0_balanced_accuracy: 0.7918  |  0:00:42s
# epoch 87 | loss: 0.47126 | val_0_balanced_accuracy: 0.79921 |  0:00:42s
# epoch 88 | loss: 0.45706 | val_0_balanced_accuracy: 0.79339 |  0:00:43s
# epoch 89 | loss: 0.447   | val_0_balanced_accuracy: 0.80212 |  0:00:43s
# epoch 90 | loss: 0.43377 | val_0_balanced_accuracy: 0.80265 |  0:00:43s
# epoch 91 | loss: 0.44138 | val_0_balanced_accuracy: 0.80688 |  0:00:44s
# epoch 92 | loss: 0.42458 | val_0_balanced_accuracy: 0.79418 |  0:00:44s
# epoch 93 | loss: 0.408   | val_0_balanced_accuracy: 0.80847 |  0:00:45s
# epoch 94 | loss: 0.40443 | val_0_balanced_accuracy: 0.81772 |  0:00:45s
# epoch 95 | loss: 0.39969 | val_0_balanced_accuracy: 0.81032 |  0:00:46s
# epoch 96 | loss: 0.40077 | val_0_balanced_accuracy: 0.81746 |  0:00:46s
# epoch 97 | loss: 0.40959 | val_0_balanced_accuracy: 0.81005 |  0:00:47s
# epoch 98 | loss: 0.38752 | val_0_balanced_accuracy: 0.81455 |  0:00:47s
# epoch 99 | loss: 0.40003 | val_0_balanced_accuracy: 0.80476 |  0:00:48s
# epoch 100| loss: 0.4047  | val_0_balanced_accuracy: 0.81772 |  0:00:48s
# epoch 101| loss: 0.40732 | val_0_balanced_accuracy: 0.80106 |  0:00:49s
# epoch 102| loss: 0.38581 | val_0_balanced_accuracy: 0.81402 |  0:00:49s
# epoch 103| loss: 0.37926 | val_0_balanced_accuracy: 0.81852 |  0:00:50s
# epoch 104| loss: 0.37006 | val_0_balanced_accuracy: 0.82831 |  0:00:50s
# epoch 105| loss: 0.35328 | val_0_balanced_accuracy: 0.82063 |  0:00:51s
# epoch 106| loss: 0.36903 | val_0_balanced_accuracy: 0.79683 |  0:00:51s
# epoch 107| loss: 0.37594 | val_0_balanced_accuracy: 0.80476 |  0:00:52s
# epoch 108| loss: 0.36233 | val_0_balanced_accuracy: 0.82222 |  0:00:52s
# epoch 109| loss: 0.37701 | val_0_balanced_accuracy: 0.81058 |  0:00:53s
# epoch 110| loss: 0.36414 | val_0_balanced_accuracy: 0.82302 |  0:00:53s
# epoch 111| loss: 0.35697 | val_0_balanced_accuracy: 0.82011 |  0:00:54s
# epoch 112| loss: 0.36007 | val_0_balanced_accuracy: 0.8254  |  0:00:54s
# epoch 113| loss: 0.35195 | val_0_balanced_accuracy: 0.82884 |  0:00:55s
# epoch 114| loss: 0.34305 | val_0_balanced_accuracy: 0.81508 |  0:00:55s
# epoch 115| loss: 0.34579 | val_0_balanced_accuracy: 0.82646 |  0:00:56s
# epoch 116| loss: 0.34455 | val_0_balanced_accuracy: 0.82249 |  0:00:56s
# epoch 117| loss: 0.33226 | val_0_balanced_accuracy: 0.82407 |  0:00:57s
# epoch 118| loss: 0.33231 | val_0_balanced_accuracy: 0.82566 |  0:00:57s
# epoch 119| loss: 0.32056 | val_0_balanced_accuracy: 0.83307 |  0:00:57s
# epoch 120| loss: 0.31801 | val_0_balanced_accuracy: 0.81561 |  0:00:58s
# epoch 121| loss: 0.32801 | val_0_balanced_accuracy: 0.82275 |  0:00:58s
# epoch 122| loss: 0.3185  | val_0_balanced_accuracy: 0.82169 |  0:00:59s
# epoch 123| loss: 0.31816 | val_0_balanced_accuracy: 0.80582 |  0:00:59s
# epoch 124| loss: 0.30013 | val_0_balanced_accuracy: 0.82434 |  0:01:00s
# epoch 125| loss: 0.2993  | val_0_balanced_accuracy: 0.82116 |  0:01:00s
# epoch 126| loss: 0.2982  | val_0_balanced_accuracy: 0.82646 |  0:01:01s
# epoch 127| loss: 0.30599 | val_0_balanced_accuracy: 0.83333 |  0:01:01s
# epoch 128| loss: 0.28871 | val_0_balanced_accuracy: 0.83545 |  0:01:02s
# epoch 129| loss: 0.2862  | val_0_balanced_accuracy: 0.82989 |  0:01:02s
# epoch 130| loss: 0.29318 | val_0_balanced_accuracy: 0.83995 |  0:01:03s
# epoch 131| loss: 0.28418 | val_0_balanced_accuracy: 0.82884 |  0:01:03s
# epoch 132| loss: 0.28517 | val_0_balanced_accuracy: 0.8336  |  0:01:04s
# epoch 133| loss: 0.29903 | val_0_balanced_accuracy: 0.83862 |  0:01:04s
# epoch 134| loss: 0.29197 | val_0_balanced_accuracy: 0.83386 |  0:01:05s
# epoch 135| loss: 0.28761 | val_0_balanced_accuracy: 0.82487 |  0:01:05s
# epoch 136| loss: 0.28898 | val_0_balanced_accuracy: 0.8373  |  0:01:06s
# epoch 137| loss: 0.30336 | val_0_balanced_accuracy: 0.82989 |  0:01:06s
# epoch 138| loss: 0.30476 | val_0_balanced_accuracy: 0.8209  |  0:01:07s
# epoch 139| loss: 0.31455 | val_0_balanced_accuracy: 0.83413 |  0:01:07s
# epoch 140| loss: 0.29446 | val_0_balanced_accuracy: 0.82037 |  0:01:08s
# epoch 141| loss: 0.30171 | val_0_balanced_accuracy: 0.83201 |  0:01:08s
# epoch 142| loss: 0.293   | val_0_balanced_accuracy: 0.83624 |  0:01:09s
# epoch 143| loss: 0.29145 | val_0_balanced_accuracy: 0.83069 |  0:01:09s
# epoch 144| loss: 0.28447 | val_0_balanced_accuracy: 0.83122 |  0:01:09s
# epoch 145| loss: 0.27147 | val_0_balanced_accuracy: 0.83175 |  0:01:10s
# epoch 146| loss: 0.27776 | val_0_balanced_accuracy: 0.83254 |  0:01:10s
# epoch 147| loss: 0.27213 | val_0_balanced_accuracy: 0.83598 |  0:01:11s
# epoch 148| loss: 0.2771  | val_0_balanced_accuracy: 0.82989 |  0:01:11s
# epoch 149| loss: 0.26285 | val_0_balanced_accuracy: 0.82963 |  0:01:12s
# epoch 150| loss: 0.27322 | val_0_balanced_accuracy: 0.83122 |  0:01:12s
#
# Early stopping occurred at epoch 150 with best_epoch = 130 and best_val_0_balanced_accuracy = 0.83995
# Best weights from best epoch are automatically used!

# %%
clf.history
# Out:
# {'loss': [1.682010163453521, 0.9931275494725196, 0.8865977325767437, 0.8469881947919384, 0.8063921624180291, 0.7734205762124776, 0.78370681559598, 0.7785077228537732, 0.7560079034674104, 0.7284201265642882, 0.731690090442671, 0.7349997008498593, 0.7183084979048903, 0.6920879300098991, 0.6840237812390403, 0.6841735542135895, 0.6762004228916538, 0.6810150512732316, 0.6855395653050202, 0.729816140741688, 0.7219260029902114, 0.7196490972340632, 0.7106048817567304, 0.6845005153768697, 0.6641512994413022, 0.6706452113820972, 0.6827604188279921, 0.669838408313731, 0.7093854667858682, 0.6793098835087327, 0.6599170014130796, 0.6320277392128367, 0.6255310833769501, 0.6292558444450351, 0.6091215204730025, 0.6080036089744096, 0.5986264270659688, 0.593610049282222, 0.5953401045403993, 0.569632660753933, 0.5683842908242812, 0.5641822112510654, 0.5541646418537833, 0.5894453504939138, 0.5796066729479996, 0.5610276235684726, 0.542540856034247, 0.5424980822694365, 0.5371926705042521, 0.5479667002772107, 0.5345175760868786, 0.5155323518016351, 0.545530611812753, 0.552528432300692, 0.5462842807042325, 0.5485826479694831, 0.5406542938432576, 0.5310156551618426, 0.5075552069110635, 0.5100911532760297, 0.49101967332224367, 0.5061824032659042, 0.5054387331849893, 0.48134224980386264, 0.4979623013913526, 0.49983179375818376, 0.49272713335313073, 0.4952062761972821, 0.47391466853690106, 0.475024999197198, 0.462286924390776, 0.4513858159172892, 0.4911769256915575, 0.500115098230002, 0.46156016447346465, 0.4524028341816426, 0.4378812619828253, 0.4525035969794743, 0.4513062980860419, 0.4478426044580167, 0.4510646671634923, 0.43352992981409477, 0.417552697406244, 0.4139566308291501, 0.4393194022317412, 0.4492776995403216, 0.4843587326625037, 0.47126029101208616, 0.4570645486656741, 0.44700171552217405, 0.43376749528989167, 0.4413839914601106, 0.42457538749595586, 0.4079970472599043, 0.40443350794664346, 0.3996850585495984, 0.40077268117529585, 0.4095891241358702, 0.3875150700620453, 0.4000320717245603, 0.4047008060904407, 0.4073174918665037, 0.385811930274627, 0.37926183954748527, 0.3700606035071916, 0.35327640876988675, 0.3690257141934921, 0.3759396018489959, 0.36233100980467686, 0.3770069728978307, 0.3641386923125602, 0.356968907925187, 0.3600746924704765, 0.35194674557899464, 0.34304923533972825, 0.34578961339997655, 0.34455329920879746, 0.33226056057940084, 0.33231070086859316, 0.3205594161725759, 0.31800905000385576, 0.3280080619207345, 0.318496941458401, 0.31816440797566947, 0.3001337235041186, 0.2992950995027283, 0.2981976660050623, 0.3059902120940059, 0.28870967844175915, 0.2862024039923619, 0.2931839293062792, 0.28417947179846453, 0.2851699917194494, 0.299027697171694, 0.2919657661591047, 0.28760928773375416, 0.28898196783856317, 0.30335632885364416, 0.3047634342570364, 0.3145454325583456, 0.29446380188856175, 0.30171322491433883, 0.2930010609525852, 0.2914516422168288, 0.2844663963010912, 0.2714717955290746, 0.2777585505072612, 0.2721312962406737, 0.2771038694987221, 0.2628465963419152, 0.27321878787281234], 'lr': [0.02, 0.02, 0.02, 0.02, 0.02, 0.02, 0.02, 0.02, 0.02, 0.02, 0.02, 0.02, 0.02, 0.02, 0.02, 0.019, 0.019, 0.019, 0.019, 0.019, 0.019, 0.019, 0.019, 0.019, 0.019, 0.019, 0.019, 0.019, 0.019, 0.019, 0.01805, 0.01805, 0.01805, 0.01805, 0.01805, 0.01805, 0.01805, 0.01805, 0.01805, 0.01805, 0.01805, 0.01805, 0.01805, 0.01805, 0.01805, 0.0171475, 0.0171475, 0.0171475, 0.0171475, 0.0171475, 0.0171475, 0.0171475, 0.0171475, 0.0171475, 0.0171475, 0.0171475, 0.0171475, 0.0171475, 0.0171475, 0.0171475, 0.016290125, 0.016290125, 0.016290125, 0.016290125, 0.016290125, 0.016290125, 0.016290125, 0.016290125, 0.016290125, 0.016290125, 0.016290125, 0.016290125, 0.016290125, 0.016290125, 0.016290125, 0.015475618749999998, 0.015475618749999998, 0.015475618749999998, 0.015475618749999998, 0.015475618749999998, 0.015475618749999998, 0.015475618749999998, 0.015475618749999998, 0.015475618749999998, 0.015475618749999998, 0.015475618749999998, 0.015475618749999 ...

# %%
y_preds = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_preds)
roc_auc = roc_auc_score(y_test, clf.predict_proba(X_test), multi_class='ovr')
f1 = f1_score(y_test, y_preds, average="macro")
print(f"Accuracy: {accuracy}\nROC-AUC: {roc_auc}")
# Out:
# Accuracy: 0.7015490588310137
# ROC-AUC: 0.9505092037247387

# %% [markdown]
# ## CatBoost Comparison

# %%
catboost = CatBoostClassifier(verbose=0) 
catboost.fit(X_train, y_train)

y_preds = catboost.predict(X_test)
accuracy = accuracy_score(y_test, y_preds)
roc_auc = roc_auc_score(y_test, catboost.predict_proba(X_test), multi_class='ovr')
f1 = f1_score(y_test, y_preds, average="macro")
print(f"Catboost Accuracy: {accuracy}\nCatboost ROC-AUC: {roc_auc}")
# Out:
# Catboost Accuracy: 0.723685791635153
# Catboost ROC-AUC: 0.9604494980569805

# %% [markdown]
# ## Explainable TabNet

# %%
clf.feature_importances_
# Out:
# array([2.21885300e-01, 5.62143748e-03, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 2.15307947e-02, 1.12806866e-02, 9.44496728e-03,
#        1.69580841e-06, 2.48604087e-02, 3.43196964e-02, 0.00000000e+00,
#        0.00000000e+00, 2.40914036e-01, 0.00000000e+00, 7.08053450e-03,
#        1.25902705e-02, 0.00000000e+00, 1.44919480e-02, 1.39460668e-02,
#        0.00000000e+00, 1.46982905e-04, 3.86808646e-02, 6.12716889e-02,
#        3.40065982e-03, 6.79061625e-06, 3.99564845e-02, 2.09382035e-02,
#        2.42823729e-02, 0.00000000e+00, 8.84775260e-03, 9.47845876e-03,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.87680836e-06, 3.02454100e-02, 0.00000000e+00,
#        8.78658529e-04, 2.18933153e-06, 4.73703973e-02, 1.39294116e-02,
#        0.00000000e+00, 0.00000000e+00, 1.51779698e-02, 1.69791784e-03,
#        1.31315720e-02, 0.00000000e+00, 0.00000000e+00, 2.50102922e-02,
#        0.00000000e+00, 2.75762020e-02])

# %%
explain_matrix, masks = clf.explain(X_test)

# %%
fig, axs = plt.subplots(1, 3, figsize=(10,10))
for i in range(len(masks)):
  axs[i].imshow(masks[i][:100],cmap="gray")
  axs[i].set_title(f"mask {i}")

# %%
fig = plt.figure(figsize=(10,10))
plt.imshow(explain_matrix[:100],cmap="gray")

# %% [markdown]
# ## Highly Imbalanced Dataset: Seismic Bumps
#
# Seismic hazard is the hardest detectable and predictable of natural hazards and in
# this respect it is comparable to an earthquake. More and more advanced seismic and seismoacoustic
# monitoring systems allow a better understanding rock mass processes and definition of seismic hazard
# prediction methods. Accuracy of so far created methods is however far from perfect. Good prediction
# of increased seismic activity is therefore a matter of great practical importance. The presented data
# set is characterized by unbalanced distribution of positive and negative examples. In the data set there
# are only 170 positive examples representing class 1.

# %%
def gmean(y_true, y_pred):
    return np.sqrt(sensitivity_score(y_true, y_pred) * specificity_score(y_true,y_pred))

# %%
subsample = 300

base_data_path = "/content/drive/MyDrive/applied_ai_enes_safak/datasets/"
forest_cover_type_dataset = base_data_path + "seismic_bumps.csv"

data = pd.read_csv(forest_cover_type_dataset).drop(["id"],axis=1)
data_wo_0 = data[data["class"] != 0]
data_w0_undersampled = data[data["class"] == 0].sample(subsample).reset_index(drop=True)

data_c = pd.concat([data_wo_0, data_w0_undersampled],axis=0).sample(frac=1).reset_index(drop=True)

# %%
data_c["class"].value_counts()
# Out:
# 0    300
# 1    170
# Name: class, dtype: int64

# %%
cont_cols = data_c.drop(["class"],axis=1)._get_numeric_data().columns
cat_cols = list(set(data_c.drop(["class"],axis=1).columns) - set(cont_cols))

data_c["seismic"] = data_c["seismic"].factorize()[0]
data_c["seismoacoustic"] = data_c["seismoacoustic"].factorize()[0]
data_c["shift"] = data_c["shift"].factorize()[0]
data_c["ghazard"] = data_c["ghazard"].factorize()[0]

cat_cols_idx = [data_c.columns.to_list().index(i) for i in cat_cols]

# %%
X_train, X_test, y_train, y_test = train_test_split(data_c.iloc[:,:-1].values,data_c.iloc[:,-1].values,test_size = 0.33)

# %%
len_unique_cat = [len(np.unique(X_train[:,data.columns.to_list().index(i)])) for i in cat_cols]

# %%
clf = TabNetClassifier(
    lambda_sparse = 1e-2,
    n_d = 8,
    n_a = 8,
    gamma = 1.5,
    optimizer_params=dict(lr=0.05),
    scheduler_params={"gamma":0.95, "verbose":0, "step_size":15},
    #scheduler_fn = torch.optim.lr_scheduler.ExponentialLR,
    scheduler_fn = torch.optim.lr_scheduler.StepLR,
    #optimizer_fn = torch.optim.AdamW
    optimizer_fn = torch.optim.Adam,
    cat_idxs = cat_cols_idx,
    cat_dims = len_unique_cat
)
# Out:
# Device used : cuda

# %%
clf.fit(
    X_train = X_train,
    y_train = y_train,
    eval_set = [(X_test, y_test)],
    max_epochs = 1000,
    batch_size = 1024,
    virtual_batch_size = 128,
    num_workers = 0,
    patience = 20,
    drop_last = False,
    eval_metric=['auc']
)
# Out:
# epoch 0  | loss: 1.07376 | val_0_auc: 0.51923 |  0:00:00s
# epoch 1  | loss: 0.72951 | val_0_auc: 0.50119 |  0:00:00s
# epoch 2  | loss: 0.67269 | val_0_auc: 0.51218 |  0:00:00s
# epoch 3  | loss: 0.68094 | val_0_auc: 0.49057 |  0:00:00s
# epoch 4  | loss: 0.61045 | val_0_auc: 0.53206 |  0:00:00s
# epoch 5  | loss: 0.60235 | val_0_auc: 0.56778 |  0:00:00s
# epoch 6  | loss: 0.57507 | val_0_auc: 0.61467 |  0:00:00s
# epoch 7  | loss: 0.60057 | val_0_auc: 0.65241 |  0:00:00s
# epoch 8  | loss: 0.55924 | val_0_auc: 0.62685 |  0:00:00s
# epoch 9  | loss: 0.56227 | val_0_auc: 0.61403 |  0:00:00s
# epoch 10 | loss: 0.58121 | val_0_auc: 0.61944 |  0:00:00s
# epoch 11 | loss: 0.54583 | val_0_auc: 0.61742 |  0:00:00s
# epoch 12 | loss: 0.56463 | val_0_auc: 0.62979 |  0:00:00s
# epoch 13 | loss: 0.58659 | val_0_auc: 0.64545 |  0:00:00s
# epoch 14 | loss: 0.56752 | val_0_auc: 0.58161 |  0:00:00s
# epoch 15 | loss: 0.5617  | val_0_auc: 0.55514 |  0:00:00s
# epoch 16 | loss: 0.53297 | val_0_auc: 0.55752 |  0:00:00s
# epoch 17 | loss: 0.53303 | val_0_auc: 0.59681 |  0:00:00s
# epoch 18 | loss: 0.53558 | val_0_auc: 0.61348 |  0:00:00s
# epoch 19 | loss: 0.53254 | val_0_auc: 0.6384  |  0:00:00s
# epoch 20 | loss: 0.51871 | val_0_auc: 0.66752 |  0:00:00s
# epoch 21 | loss: 0.50807 | val_0_auc: 0.66935 |  0:00:00s
# epoch 22 | loss: 0.53026 | val_0_auc: 0.67119 |  0:00:00s
# epoch 23 | loss: 0.52358 | val_0_auc: 0.67467 |  0:00:00s
# epoch 24 | loss: 0.5185  | val_0_auc: 0.69115 |  0:00:01s
# epoch 25 | loss: 0.52086 | val_0_auc: 0.65983 |  0:00:01s
# epoch 26 | loss: 0.53196 | val_0_auc: 0.65708 |  0:00:01s
# epoch 27 | loss: 0.50707 | val_0_auc: 0.66175 |  0:00:01s
# epoch 28 | loss: 0.50627 | val_0_auc: 0.66816 |  0:00:01s
# epoch 29 | loss: 0.53536 | val_0_auc: 0.66835 |  0:00:01s
# epoch 30 | loss: 0.50893 | val_0_auc: 0.68648 |  0:00:01s
# epoch 31 | loss: 0.51031 | val_0_auc: 0.70443 |  0:00:01s
# epoch 32 | loss: 0.52055 | val_0_auc: 0.69738 |  0:00:01s
# epoch 33 | loss: 0.50313 | val_0_auc: 0.72632 |  0:00:01s
# epoch 34 | loss: 0.50355 | val_0_auc: 0.74904 |  0:00:01s
# epoch 35 | loss: 0.51328 | val_0_auc: 0.74812 |  0:00:01s
# epoch 36 | loss: 0.53592 | val_0_auc: 0.74464 |  0:00:01s
# epoch 37 | loss: 0.50726 | val_0_auc: 0.74409 |  0:00:01s
# epoch 38 | loss: 0.49948 | val_0_auc: 0.73805 |  0:00:01s
# epoch 39 | loss: 0.50273 | val_0_auc: 0.72385 |  0:00:01s
# epoch 40 | loss: 0.49256 | val_0_auc: 0.71799 |  0:00:01s
# epoch 41 | loss: 0.49373 | val_0_auc: 0.70452 |  0:00:01s
# epoch 42 | loss: 0.48276 | val_0_auc: 0.68987 |  0:00:01s
# epoch 43 | loss: 0.49107 | val_0_auc: 0.6884  |  0:00:01s
# epoch 44 | loss: 0.46871 | val_0_auc: 0.68785 |  0:00:01s
# epoch 45 | loss: 0.48687 | val_0_auc: 0.68785 |  0:00:01s
# epoch 46 | loss: 0.49439 | val_0_auc: 0.68034 |  0:00:01s
# epoch 47 | loss: 0.47502 | val_0_auc: 0.68602 |  0:00:01s
# epoch 48 | loss: 0.47007 | val_0_auc: 0.68676 |  0:00:01s
# epoch 49 | loss: 0.47294 | val_0_auc: 0.68401 |  0:00:01s
# epoch 50 | loss: 0.46115 | val_0_auc: 0.67888 |  0:00:02s
# epoch 51 | loss: 0.47829 | val_0_auc: 0.68557 |  0:00:02s
# epoch 52 | loss: 0.48165 | val_0_auc: 0.70352 |  0:00:02s
# epoch 53 | loss: 0.45706 | val_0_auc: 0.71121 |  0:00:02s
# epoch 54 | loss: 0.47592 | val_0_auc: 0.69729 |  0:00:02s
#
# Early stopping occurred at epoch 54 with best_epoch = 34 and best_val_0_auc = 0.74904
# Best weights from best epoch are automatically used!

# %%
proba = clf.predict_proba(X_test)
proba_unhot = []
for row in proba:
  proba_unhot.append(row[1])

# %%
y_preds = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_preds)
roc_auc = roc_auc_score(y_test, proba_unhot)
print(f"Accuracy: {accuracy}\nROC-AUC: {roc_auc}")
# Out:
# Accuracy: 0.7115384615384616
# ROC-AUC: 0.7490382854002564

# %%
gmean(y_test, y_preds)
# Out:
# 0.7172028465244906

# %%
confusion_matrix(y_test, y_preds)
# Out:
# array([[72, 31],
#        [14, 39]])

# %%
proba = catboost.predict_proba(X_test)
proba_unhot = []
for row in proba:
  proba_unhot.append(row[1])

catboost = CatBoostClassifier(verbose=0) 
catboost.fit(X_train, y_train)

y_preds = catboost.predict(X_test)
accuracy = accuracy_score(y_test, y_preds)
roc_auc = roc_auc_score(y_test, proba_unhot)
print(f"Catboost Accuracy: {accuracy}\nCatboost ROC-AUC: {roc_auc}")
# Out:
# Catboost Accuracy: 0.7051282051282052
# Catboost ROC-AUC: 0.8613299139036453

# %%
confusion_matrix(y_test, y_preds)
# Out:
# array([[89, 14],
#        [32, 21]])

# %%
gmean(y_test, y_preds)
# Out:
# 0.585124258178296

# %%
explain_matrix, masks = clf.explain(X_test)

# %%
fig, axs = plt.subplots(1, 3, figsize=(10,10))
for i in range(len(masks)):
  axs[i].imshow(masks[i][:100],cmap="gray")
  axs[i].set_title(f"mask {i}")

# %%
fig = plt.figure(figsize=(10,10))
plt.imshow(explain_matrix[:100],cmap="gray")
