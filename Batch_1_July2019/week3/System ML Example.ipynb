# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !java -version
# Out:
# openjdk version "11.0.3" 2019-04-16
# OpenJDK Runtime Environment (build 11.0.3+7-Ubuntu-1ubuntu218.04.1)
# OpenJDK 64-Bit Server VM (build 11.0.3+7-Ubuntu-1ubuntu218.04.1, mixed mode, sharing)

# %%
# !wget "http://www-eu.apache.org/dist/spark/spark-2.3.3/spark-2.3.3-bin-hadoop2.6.tgz"
# !tar -xvf spark-2.3.3-bin-hadoop2.6.tgz
# Out:
# --2019-07-20 08:21:31--  http://www-eu.apache.org/dist/spark/spark-2.3.3/spark-2.3.3-bin-hadoop2.6.tgz
# Resolving www-eu.apache.org (www-eu.apache.org)... 95.216.24.32, 2a01:4f9:2a:185f::2
# Connecting to www-eu.apache.org (www-eu.apache.org)|95.216.24.32|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 223791959 (213M) [application/x-gzip]
# Saving to: ‘spark-2.3.3-bin-hadoop2.6.tgz’
#
# spark-2.3.3-bin-had 100%[===================>] 213.42M  15.9MB/s    in 15s
#
# 2019-07-20 08:21:46 (14.6 MB/s) - ‘spark-2.3.3-bin-hadoop2.6.tgz’ saved [223791959/223791959]
#
# spark-2.3.3-bin-hadoop2.6/
# spark-2.3.3-bin-hadoop2.6/bin/
# spark-2.3.3-bin-hadoop2.6/bin/beeline
# spark-2.3.3-bin-hadoop2.6/bin/beeline.cmd
# spark-2.3.3-bin-hadoop2.6/bin/docker-image-tool.sh
# spark-2.3.3-bin-hadoop2.6/bin/find-spark-home
# spark-2.3.3-bin-hadoop2.6/bin/find-spark-home.cmd
# spark-2.3.3-bin-hadoop2.6/bin/load-spark-env.cmd
# spark-2.3.3-bin-hadoop2.6/bin/load-spark-env.sh
# spark-2.3.3-bin-hadoop2.6/bin/pyspark
# spark-2.3.3-bin-hadoop2.6/bin/pyspark.cmd
# spark-2.3.3-bin-hadoop2.6/bin/pyspark2.cmd
# spark-2.3.3-bin-hadoop2.6/bin/run-example
# spark-2.3.3-bin-hadoop2.6/bin/run-example.cmd
# spark-2.3.3-bin-hadoop2.6/bin/spark-class
# spark-2.3.3-bin-hadoop2.6/bin/spark-class.cmd
# spark-2.3.3-bin-hadoop2.6/bin/spark-class2.cmd
# spark-2.3.3-bin-hadoop2.6/bin/spark-shell
# spark-2.3.3-bin-hadoop2.6/bin/spark-shell.cmd
# spark-2.3.3-bin-hadoop2.6/bin/spark-shell2.cmd
# spark-2.3.3-bin-hadoop2.6/bin/spark-sql
# spark-2.3.3-bin-hadoop2.6/bin/spark-sql.cmd
# spark-2.3.3-bin-hadoop2.6/bin/spark-sql2.cmd
# spark-2.3.3-bin-hadoop2.6/bin/spark-submit
# spark-2.3.3-bin-hadoop2.6/bin/spark-submit.cmd
# spark-2.3.3-bin-hadoop2.6/bin/spark-submit2.cmd
# spark-2.3.3-bin-hadoop2.6/bin/sparkR
# spark-2.3.3-bin-hadoop2.6/bin/sparkR.cmd
# spark-2.3.3-bin-hadoop2.6/bin/sparkR2.cmd
# spark-2.3.3-bin-hadoop2.6/conf/
# spark-2.3.3-bin-hadoop2.6/conf/docker.properties.template
# spark-2.3.3-bin-hadoop2.6/conf/fairscheduler.xml.template
# spark-2.3.3-bin-hadoop2.6/conf/log4j.properties.template
# spark-2.3.3-bin-hadoop2.6/conf/metrics.properties.template
# spark-2.3.3-bin-hadoop2.6/conf/slaves.template
# spark-2.3.3-bin-hadoop2.6/conf/spark-defaults.conf.template
# spark-2.3.3-bin-hadoop2.6/conf/spark-env.sh.template
# spark-2.3.3-bin-hadoop2.6/data/
# spark-2.3.3-bin-hadoop2.6/data/graphx/
# spark-2.3.3-bin-hadoop2.6/data/graphx/followers.txt
# spark-2.3.3-bin-hadoop2.6/data/graphx/users.txt
# spark-2.3.3-bin-hadoop2.6/data/mllib/
# spark-2.3.3-bin-hadoop2.6/data/mllib/als/
# spark-2.3.3-bin-hadoop2.6/data/mllib/als/sample_movielens_ratings.txt
# spark-2.3.3-bin-hadoop2.6/data/mllib/als/test.data
# spark-2.3.3-bin-hadoop2.6/data/mllib/gmm_data.txt
# spark-2.3.3-bin-hadoop2.6/data/mllib/images/
# spark-2.3.3-bin-hadoop2.6/data/mllib/images/kittens/
# spark-2.3.3-bin-hadoop2.6/data/mllib/images/kittens/29.5.a_b_EGDP022204.jpg
# spark-2.3.3-bin-hadoop2.6/data/mllib/images/kittens/54893.jpg
# spark-2.3.3-bin-hadoop2.6/data/mllib/images/kittens/DP153539.jpg
# spark-2.3.3-bin-hadoop2.6/data/mllib/images/kittens/DP802813.jpg
# spark-2.3.3-bin-hadoop2.6/data/mllib/images/kittens/not-image.txt
# spark-2.3.3-bin-hadoop2.6/data/mllib/images/license.txt
# spark-2.3.3-bin-hadoop2.6/data/mllib/images/multi-channel/
# spark-2.3.3-bin-hadoop2.6/data/mllib/images/multi-channel/BGRA.png
# spark-2.3.3-bin-hadoop2.6/data/mllib/images/multi-channel/BGRA_alpha_60.png
# spark-2.3.3-bin-hadoop2.6/data/mllib/images/multi-channel/chr30.4.184.jpg
# spark-2.3.3-bin-hadoop2.6/data/mllib/images/multi-channel/grayscale.jpg
# spark-2.3.3-bin-hadoop2.6/data/mllib/iris_libsvm.txt
# spark-2.3.3-bin-hadoop2.6/data/mllib/kmeans_data.txt
# spark-2.3.3-bin-hadoop2.6/data/mllib/pagerank_data.txt
# spark-2.3.3-bin-hadoop2.6/data/mllib/pic_data.txt
# spark-2.3.3-bin-hadoop2.6/data/mllib/ridge-data/
# spark-2.3.3-bin-hadoop2.6/data/mllib/ridge-data/lpsa.data
# spark-2.3.3-bin-hadoop2.6/data/mllib/sample_binary_classification_data.txt
# spark-2.3.3-bin-hadoop2.6/data/mllib/sample_fpgrowth.txt
# spark-2.3.3-bin-hadoop2.6/data/mllib/sample_isotonic_regression_libsvm_data.txt
# spark-2.3.3-bin-hadoop2.6/data/mllib/sample_kmeans_data.txt
# spark-2.3.3-bin-hadoop2.6/data/mllib/sample_lda_data.txt
# spark-2.3.3-bin-hadoop2.6/data/mllib/sample_lda_libsvm_data.txt
# spark-2.3.3-bin-hadoop2.6/data/mllib/sample_libsvm_data.txt
# spark-2.3.3-bin-hadoop2.6/data/mllib/sample_linear_regression_data.txt
# spark-2.3.3-bin-hadoop2.6/data/mllib/sample_movielens_data.txt
# spark-2.3.3-bin-hadoop2.6/data/mllib/sample_multiclass_classification_data.txt
# spark-2.3.3-bin-hadoop2.6/data/mllib/sample_svm_data.txt
# spark-2.3.3-bin-hadoop2.6/data/mllib/streaming_kmeans_data_test.txt
# spark-2.3.3-bin-hadoop2.6/data/streaming/
# spark-2.3.3-bin-hadoop2.6/data/streaming/AFINN-111.txt
# spark-2.3.3-bin-hadoop2.6/examples/
# spark-2.3.3-bin-hadoop2.6/examples/jars/
# spark-2.3.3-bin-hadoop2.6/examples/jars/scopt_2.11-3.7.0.jar
# spark-2.3.3-bin-hadoop2.6/examples/jars/spark-examples_2.11-2.3.3.jar
# spark-2.3.3-bin-hadoop2.6/examples/src/
# spark-2.3.3-bin-hadoop2.6/examples/src/main/
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/JavaHdfsLR.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/JavaLogQuery.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/JavaPageRank.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/JavaSparkPi.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/JavaStatusTrackerDemo.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/JavaTC.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/JavaWordCount.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaAFTSurvivalRegressionExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaALSExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaBinarizerExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaBisectingKMeansExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaBucketedRandomProjectionLSHExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaBucketizerExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaChiSqSelectorExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaChiSquareTestExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaCorrelationExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaCountVectorizerExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaDCTExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaDecisionTreeClassificationExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaDecisionTreeRegressionExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaDocument.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaElementwiseProductExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaEstimatorTransformerParamExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaFeatureHasherExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaFPGrowthExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaGaussianMixtureExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaGeneralizedLinearRegressionExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaGradientBoostedTreeClassifierExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaGradientBoostedTreeRegressorExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaImputerExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaIndexToStringExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaInteractionExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaIsotonicRegressionExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaKMeansExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaLabeledDocument.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaLDAExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaLinearRegressionWithElasticNetExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaLinearSVCExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaLogisticRegressionSummaryExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaLogisticRegressionWithElasticNetExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaMaxAbsScalerExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaMinHashLSHExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaMinMaxScalerExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaModelSelectionViaCrossValidationExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaModelSelectionViaTrainValidationSplitExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaMulticlassLogisticRegressionWithElasticNetExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaMultilayerPerceptronClassifierExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaNaiveBayesExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaNGramExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaNormalizerExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaOneHotEncoderEstimatorExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaOneVsRestExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaPCAExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaPipelineExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaPolynomialExpansionExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaQuantileDiscretizerExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaRandomForestClassifierExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaRandomForestRegressorExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaRFormulaExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaSQLTransformerExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaStandardScalerExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaStopWordsRemoverExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaStringIndexerExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaTfIdfExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaTokenizerExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaVectorAssemblerExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaVectorIndexerExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaVectorSizeHintExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaVectorSlicerExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/ml/JavaWord2VecExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaALS.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaAssociationRulesExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaBinaryClassificationMetricsExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaBisectingKMeansExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaChiSqSelectorExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaCorrelationsExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaDecisionTreeClassificationExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaDecisionTreeRegressionExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaElementwiseProductExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaGaussianMixtureExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaGradientBoostingClassificationExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaGradientBoostingRegressionExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaHypothesisTestingExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaHypothesisTestingKolmogorovSmirnovTestExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaIsotonicRegressionExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaKernelDensityEstimationExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaKMeansExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaLatentDirichletAllocationExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaLBFGSExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaLinearRegressionWithSGDExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaLogisticRegressionWithLBFGSExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaMulticlassClassificationMetricsExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaMultiLabelClassificationMetricsExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaNaiveBayesExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaPCAExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaPowerIterationClusteringExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaPrefixSpanExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaRandomForestClassificationExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaRandomForestRegressionExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaRankingMetricsExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaRecommendationExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaRegressionMetricsExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaSimpleFPGrowth.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaStratifiedSamplingExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaStreamingTestExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaSummaryStatisticsExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaSVDExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/mllib/JavaSVMWithSGDExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/sql/
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/sql/hive/
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/sql/hive/JavaSparkHiveExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/sql/JavaSparkSQLExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/sql/JavaSQLDataSourceExample.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/sql/JavaUserDefinedTypedAggregation.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/sql/JavaUserDefinedUntypedAggregation.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/sql/streaming/
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/sql/streaming/JavaStructuredKafkaWordCount.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/sql/streaming/JavaStructuredNetworkWordCount.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/sql/streaming/JavaStructuredNetworkWordCountWindowed.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/sql/streaming/JavaStructuredSessionization.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/streaming/
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/streaming/JavaCustomReceiver.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/streaming/JavaDirectKafkaWordCount.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/streaming/JavaNetworkWordCount.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/streaming/JavaQueueStream.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/streaming/JavaRecord.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/streaming/JavaRecoverableNetworkWordCount.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/streaming/JavaSqlNetworkWordCount.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/java/org/apache/spark/examples/streaming/JavaStatefulNetworkWordCount.java
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/als.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/avro_inputformat.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/kmeans.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/logistic_regression.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/aft_survival_regression.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/als_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/binarizer_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/bisecting_k_means_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/bucketed_random_projection_lsh_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/bucketizer_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/chi_square_test_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/chisq_selector_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/correlation_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/count_vectorizer_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/cross_validator.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/dataframe_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/dct_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/decision_tree_classification_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/decision_tree_regression_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/elementwise_product_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/estimator_transformer_param_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/feature_hasher_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/fpgrowth_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/gaussian_mixture_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/generalized_linear_regression_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/gradient_boosted_tree_classifier_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/gradient_boosted_tree_regressor_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/imputer_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/index_to_string_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/isotonic_regression_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/kmeans_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/lda_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/linear_regression_with_elastic_net.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/linearsvc.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/logistic_regression_summary_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/logistic_regression_with_elastic_net.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/max_abs_scaler_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/min_hash_lsh_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/min_max_scaler_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/multiclass_logistic_regression_with_elastic_net.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/multilayer_perceptron_classification.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/n_gram_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/naive_bayes_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/normalizer_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/one_vs_rest_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/onehot_encoder_estimator_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/pca_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/pipeline_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/polynomial_expansion_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/quantile_discretizer_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/random_forest_classifier_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/random_forest_regressor_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/rformula_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/sql_transformer.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/standard_scaler_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/stopwords_remover_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/string_indexer_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/tf_idf_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/tokenizer_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/train_validation_split.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/vector_assembler_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/vector_indexer_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/vector_size_hint_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/vector_slicer_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/ml/word2vec_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/binary_classification_metrics_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/bisecting_k_means_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/correlations.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/correlations_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/decision_tree_classification_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/decision_tree_regression_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/elementwise_product_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/fpgrowth_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/gaussian_mixture_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/gaussian_mixture_model.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/gradient_boosting_classification_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/gradient_boosting_regression_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/hypothesis_testing_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/hypothesis_testing_kolmogorov_smirnov_test_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/isotonic_regression_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/k_means_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/kernel_density_estimation_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/kmeans.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/latent_dirichlet_allocation_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/linear_regression_with_sgd_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/logistic_regression.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/logistic_regression_with_lbfgs_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/multi_class_metrics_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/multi_label_metrics_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/naive_bayes_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/normalizer_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/pca_rowmatrix_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/power_iteration_clustering_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/random_forest_classification_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/random_forest_regression_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/random_rdd_generation.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/ranking_metrics_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/recommendation_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/regression_metrics_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/sampled_rdds.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/standard_scaler_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/stratified_sampling_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/streaming_k_means_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/streaming_linear_regression_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/summary_statistics_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/svd_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/svm_with_sgd_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/tf_idf_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/word2vec.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/mllib/word2vec_example.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/pagerank.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/parquet_inputformat.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/pi.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/sort.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/sql/
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/sql/arrow.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/sql/basic.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/sql/datasource.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/sql/hive.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/sql/streaming/
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/sql/streaming/structured_kafka_wordcount.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/sql/streaming/structured_network_wordcount.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/sql/streaming/structured_network_wordcount_windowed.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/status_api_demo.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/streaming/
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/streaming/direct_kafka_wordcount.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/streaming/flume_wordcount.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/streaming/hdfs_wordcount.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/streaming/kafka_wordcount.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/streaming/network_wordcount.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/streaming/network_wordjoinsentiments.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/streaming/queue_stream.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/streaming/recoverable_network_wordcount.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/streaming/sql_network_wordcount.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/streaming/stateful_network_wordcount.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/transitive_closure.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/python/wordcount.py
# spark-2.3.3-bin-hadoop2.6/examples/src/main/r/
# spark-2.3.3-bin-hadoop2.6/examples/src/main/r/data-manipulation.R
# spark-2.3.3-bin-hadoop2.6/examples/src/main/r/dataframe.R
# spark-2.3.3-bin-hadoop2.6/examples/src/main/r/ml/
# spark-2.3.3-bin-hadoop2.6/examples/src/main/r/ml/als.R
# spark-2.3.3-bin-hadoop2.6/examples/src/main/r/ml/bisectingKmeans.R
# spark-2.3.3-bin-hadoop2.6/examples/src/main/r/ml/decisionTree.R
# spark-2.3.3-bin-hadoop2.6/examples/src/main/r/ml/fpm.R
# spark-2.3.3-bin-hadoop2.6/examples/src/main/r/ml/gaussianMixture.R
# spark-2.3.3-bin-hadoop2.6/examples/src/main/r/ml/gbt.R
# spark-2.3.3-bin-hadoop2.6/examples/src/main/r/ml/glm.R
# spark-2.3.3-bin-hadoop2.6/examples/src/main/r/ml/isoreg.R
# spark-2.3.3-bin-hadoop2.6/examples/src/main/r/ml/kmeans.R
# spark-2.3.3-bin-hadoop2.6/examples/src/main/r/ml/kstest.R
# spark-2.3.3-bin-hadoop2.6/examples/src/main/r/ml/lda.R
# spark-2.3.3-bin-hadoop2.6/examples/src/main/r/ml/logit.R
# spark-2.3.3-bin-hadoop2.6/examples/src/main/r/ml/ml.R
# spark-2.3.3-bin-hadoop2.6/examples/src/main/r/ml/mlp.R
# spark-2.3.3-bin-hadoop2.6/examples/src/main/r/ml/naiveBayes.R
# spark-2.3.3-bin-hadoop2.6/examples/src/main/r/ml/randomForest.R
# spark-2.3.3-bin-hadoop2.6/examples/src/main/r/ml/survreg.R
# spark-2.3.3-bin-hadoop2.6/examples/src/main/r/ml/svmLinear.R
# spark-2.3.3-bin-hadoop2.6/examples/src/main/r/RSparkSQLExample.R
# spark-2.3.3-bin-hadoop2.6/examples/src/main/r/streaming/
# spark-2.3.3-bin-hadoop2.6/examples/src/main/r/streaming/structured_network_wordcount.R
# spark-2.3.3-bin-hadoop2.6/examples/src/main/resources/
# spark-2.3.3-bin-hadoop2.6/examples/src/main/resources/employees.json
# spark-2.3.3-bin-hadoop2.6/examples/src/main/resources/full_user.avsc
# spark-2.3.3-bin-hadoop2.6/examples/src/main/resources/kv1.txt
# spark-2.3.3-bin-hadoop2.6/examples/src/main/resources/people.csv
# spark-2.3.3-bin-hadoop2.6/examples/src/main/resources/people.json
# spark-2.3.3-bin-hadoop2.6/examples/src/main/resources/people.txt
# spark-2.3.3-bin-hadoop2.6/examples/src/main/resources/user.avsc
# spark-2.3.3-bin-hadoop2.6/examples/src/main/resources/users.avro
# spark-2.3.3-bin-hadoop2.6/examples/src/main/resources/users.parquet
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/BroadcastTest.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/DFSReadWriteTest.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/DriverSubmissionTest.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ExceptionHandlingTest.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/graphx/
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/graphx/AggregateMessagesExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/graphx/Analytics.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/graphx/ComprehensiveExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/graphx/ConnectedComponentsExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/graphx/LiveJournalPageRank.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/graphx/PageRankExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/graphx/SSSPExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/graphx/SynthBenchmark.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/graphx/TriangleCountingExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/GroupByTest.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/HdfsTest.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/LocalALS.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/LocalFileLR.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/LocalKMeans.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/LocalLR.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/LocalPi.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/LogQuery.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/AFTSurvivalRegressionExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/ALSExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/BinarizerExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/BisectingKMeansExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/BucketedRandomProjectionLSHExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/BucketizerExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/ChiSqSelectorExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/ChiSquareTestExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/CorrelationExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/CountVectorizerExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/DataFrameExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/DCTExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/DecisionTreeClassificationExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/DecisionTreeExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/DecisionTreeRegressionExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/DeveloperApiExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/ElementwiseProductExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/EstimatorTransformerParamExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/FeatureHasherExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/FPGrowthExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/GaussianMixtureExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/GBTExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/GeneralizedLinearRegressionExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/GradientBoostedTreeClassifierExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/GradientBoostedTreeRegressorExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/ImputerExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/IndexToStringExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/InteractionExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/IsotonicRegressionExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/KMeansExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/LDAExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/LinearRegressionExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/LinearRegressionWithElasticNetExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/LinearSVCExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/LogisticRegressionExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/LogisticRegressionSummaryExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/LogisticRegressionWithElasticNetExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/MaxAbsScalerExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/MinHashLSHExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/MinMaxScalerExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/ModelSelectionViaCrossValidationExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/ModelSelectionViaTrainValidationSplitExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/MulticlassLogisticRegressionWithElasticNetExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/MultilayerPerceptronClassifierExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/NaiveBayesExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/NGramExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/NormalizerExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/OneHotEncoderEstimatorExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/OneVsRestExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/PCAExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/PipelineExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/PolynomialExpansionExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/QuantileDiscretizerExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/RandomForestClassifierExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/RandomForestExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/RandomForestRegressorExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/RFormulaExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/SQLTransformerExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/StandardScalerExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/StopWordsRemoverExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/StringIndexerExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/TfIdfExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/TokenizerExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/UnaryTransformerExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/VectorAssemblerExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/VectorIndexerExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/VectorSizeHintExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/VectorSlicerExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/ml/Word2VecExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/AbstractParams.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/AssociationRulesExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/BinaryClassification.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/BinaryClassificationMetricsExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/BisectingKMeansExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/ChiSqSelectorExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/Correlations.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/CorrelationsExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/CosineSimilarity.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/DecisionTreeClassificationExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/DecisionTreeRegressionExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/DecisionTreeRunner.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/DenseKMeans.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/ElementwiseProductExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/FPGrowthExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/GaussianMixtureExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/GradientBoostedTreesRunner.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/GradientBoostingClassificationExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/GradientBoostingRegressionExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/HypothesisTestingExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/HypothesisTestingKolmogorovSmirnovTestExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/IsotonicRegressionExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/KernelDensityEstimationExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/KMeansExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/LatentDirichletAllocationExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/LBFGSExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/LDAExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/LinearRegression.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/LinearRegressionWithSGDExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/LogisticRegressionWithLBFGSExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/MovieLensALS.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/MulticlassMetricsExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/MultiLabelMetricsExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/MultivariateSummarizer.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/NaiveBayesExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/NormalizerExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/PCAExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/PCAOnRowMatrixExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/PCAOnSourceVectorExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/PMMLModelExportExample.scala
# spark-2.3.3-bin-hadoop2.6/examples/src/main/scala/org/apache/spark/examples/mllib/PowerIterationClusteringExample.scala
# ...
# spark-2.3.3-bin-hadoop2.6/licenses/LICENSE-modernizr.txt
# spark-2.3.3-bin-hadoop2.6/licenses/LICENSE-netlib.txt
# spark-2.3.3-bin-hadoop2.6/licenses/LICENSE-paranamer.txt
# spark-2.3.3-bin-hadoop2.6/licenses/LICENSE-postgresql.txt
# spark-2.3.3-bin-hadoop2.6/licenses/LICENSE-protobuf.txt
# spark-2.3.3-bin-hadoop2.6/licenses/LICENSE-py4j.txt
# spark-2.3.3-bin-hadoop2.6/licenses/LICENSE-pyrolite.txt
# spark-2.3.3-bin-hadoop2.6/licenses/LICENSE-reflectasm.txt
# spark-2.3.3-bin-hadoop2.6/licenses/LICENSE-sbt-launch-lib.txt
# spark-2.3.3-bin-hadoop2.6/licenses/LICENSE-scala.txt
# spark-2.3.3-bin-hadoop2.6/licenses/LICENSE-scalacheck.txt
# spark-2.3.3-bin-hadoop2.6/licenses/LICENSE-scopt.txt
# spark-2.3.3-bin-hadoop2.6/licenses/LICENSE-slf4j.txt
# spark-2.3.3-bin-hadoop2.6/licenses/LICENSE-SnapTree.txt
# spark-2.3.3-bin-hadoop2.6/licenses/LICENSE-sorttable.js.txt
# spark-2.3.3-bin-hadoop2.6/licenses/LICENSE-spire.txt
# spark-2.3.3-bin-hadoop2.6/licenses/LICENSE-xmlenc.txt
# spark-2.3.3-bin-hadoop2.6/licenses/LICENSE-zstd-jni.txt
# spark-2.3.3-bin-hadoop2.6/licenses/LICENSE-zstd.txt
# spark-2.3.3-bin-hadoop2.6/NOTICE
# spark-2.3.3-bin-hadoop2.6/python/
# spark-2.3.3-bin-hadoop2.6/python/.gitignore
# spark-2.3.3-bin-hadoop2.6/python/docs/
# spark-2.3.3-bin-hadoop2.6/python/docs/_static/
# spark-2.3.3-bin-hadoop2.6/python/docs/_static/pyspark.css
# spark-2.3.3-bin-hadoop2.6/python/docs/_static/pyspark.js
# spark-2.3.3-bin-hadoop2.6/python/docs/_templates/
# spark-2.3.3-bin-hadoop2.6/python/docs/_templates/layout.html
# spark-2.3.3-bin-hadoop2.6/python/docs/conf.py
# spark-2.3.3-bin-hadoop2.6/python/docs/epytext.py
# spark-2.3.3-bin-hadoop2.6/python/docs/index.rst
# spark-2.3.3-bin-hadoop2.6/python/docs/make.bat
# spark-2.3.3-bin-hadoop2.6/python/docs/make2.bat
# spark-2.3.3-bin-hadoop2.6/python/docs/Makefile
# spark-2.3.3-bin-hadoop2.6/python/docs/pyspark.ml.rst
# spark-2.3.3-bin-hadoop2.6/python/docs/pyspark.mllib.rst
# spark-2.3.3-bin-hadoop2.6/python/docs/pyspark.rst
# spark-2.3.3-bin-hadoop2.6/python/docs/pyspark.sql.rst
# spark-2.3.3-bin-hadoop2.6/python/docs/pyspark.streaming.rst
# spark-2.3.3-bin-hadoop2.6/python/lib/
# spark-2.3.3-bin-hadoop2.6/python/lib/py4j-0.10.7-src.zip
# spark-2.3.3-bin-hadoop2.6/python/lib/PY4J_LICENSE.txt
# spark-2.3.3-bin-hadoop2.6/python/lib/pyspark.zip
# spark-2.3.3-bin-hadoop2.6/python/MANIFEST.in
# spark-2.3.3-bin-hadoop2.6/python/pylintrc
# spark-2.3.3-bin-hadoop2.6/python/pyspark/
# spark-2.3.3-bin-hadoop2.6/python/pyspark/__init__.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/_globals.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/accumulators.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/broadcast.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/cloudpickle.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/conf.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/context.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/daemon.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/files.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/find_spark_home.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/heapq3.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/java_gateway.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/join.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/ml/
# spark-2.3.3-bin-hadoop2.6/python/pyspark/ml/__init__.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/ml/base.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/ml/classification.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/ml/clustering.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/ml/common.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/ml/evaluation.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/ml/feature.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/ml/fpm.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/ml/image.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/ml/linalg/
# spark-2.3.3-bin-hadoop2.6/python/pyspark/ml/linalg/__init__.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/ml/param/
# spark-2.3.3-bin-hadoop2.6/python/pyspark/ml/param/__init__.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/ml/param/_shared_params_code_gen.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/ml/param/shared.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/ml/pipeline.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/ml/recommendation.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/ml/regression.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/ml/stat.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/ml/tests.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/ml/tuning.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/ml/util.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/ml/wrapper.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/mllib/
# spark-2.3.3-bin-hadoop2.6/python/pyspark/mllib/__init__.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/mllib/classification.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/mllib/clustering.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/mllib/common.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/mllib/evaluation.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/mllib/feature.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/mllib/fpm.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/mllib/linalg/
# spark-2.3.3-bin-hadoop2.6/python/pyspark/mllib/linalg/__init__.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/mllib/linalg/distributed.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/mllib/random.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/mllib/recommendation.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/mllib/regression.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/mllib/stat/
# spark-2.3.3-bin-hadoop2.6/python/pyspark/mllib/stat/__init__.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/mllib/stat/_statistics.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/mllib/stat/distribution.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/mllib/stat/KernelDensity.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/mllib/stat/test.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/mllib/tests.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/mllib/tree.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/mllib/util.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/profiler.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/rdd.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/rddsampler.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/resultiterable.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/serializers.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/shell.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/shuffle.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/sql/
# spark-2.3.3-bin-hadoop2.6/python/pyspark/sql/__init__.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/sql/catalog.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/sql/column.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/sql/conf.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/sql/context.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/sql/dataframe.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/sql/functions.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/sql/group.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/sql/readwriter.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/sql/session.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/sql/streaming.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/sql/tests.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/sql/types.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/sql/udf.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/sql/utils.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/sql/window.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/statcounter.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/status.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/storagelevel.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/streaming/
# spark-2.3.3-bin-hadoop2.6/python/pyspark/streaming/__init__.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/streaming/context.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/streaming/dstream.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/streaming/flume.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/streaming/kafka.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/streaming/kinesis.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/streaming/listener.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/streaming/tests.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/streaming/util.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/taskcontext.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/test_broadcast.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/test_serializers.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/tests.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/traceback_utils.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/util.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/version.py
# spark-2.3.3-bin-hadoop2.6/python/pyspark/worker.py
# spark-2.3.3-bin-hadoop2.6/python/README.md
# spark-2.3.3-bin-hadoop2.6/python/run-tests
# spark-2.3.3-bin-hadoop2.6/python/run-tests.py
# spark-2.3.3-bin-hadoop2.6/python/setup.cfg
# spark-2.3.3-bin-hadoop2.6/python/setup.py
# spark-2.3.3-bin-hadoop2.6/python/test_support/
# spark-2.3.3-bin-hadoop2.6/python/test_support/hello/
# spark-2.3.3-bin-hadoop2.6/python/test_support/hello/hello.txt
# spark-2.3.3-bin-hadoop2.6/python/test_support/hello/sub_hello/
# spark-2.3.3-bin-hadoop2.6/python/test_support/hello/sub_hello/sub_hello.txt
# spark-2.3.3-bin-hadoop2.6/python/test_support/SimpleHTTPServer.py
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/ages.csv
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/ages_newlines.csv
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/orc_partitioned/
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/orc_partitioned/_SUCCESS
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/orc_partitioned/b=0/
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/orc_partitioned/b=0/c=0/
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/orc_partitioned/b=0/c=0/.part-r-00000-829af031-b970-49d6-ad39-30460a0be2c8.orc.crc
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/orc_partitioned/b=0/c=0/part-r-00000-829af031-b970-49d6-ad39-30460a0be2c8.orc
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/orc_partitioned/b=1/
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/orc_partitioned/b=1/c=1/
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/orc_partitioned/b=1/c=1/.part-r-00000-829af031-b970-49d6-ad39-30460a0be2c8.orc.crc
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/orc_partitioned/b=1/c=1/part-r-00000-829af031-b970-49d6-ad39-30460a0be2c8.orc
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/parquet_partitioned/
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/parquet_partitioned/_common_metadata
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/parquet_partitioned/_metadata
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/parquet_partitioned/_SUCCESS
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/parquet_partitioned/year=2014/
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/parquet_partitioned/year=2014/month=9/
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/parquet_partitioned/year=2014/month=9/day=1/
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/parquet_partitioned/year=2014/month=9/day=1/.part-r-00008.gz.parquet.crc
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/parquet_partitioned/year=2014/month=9/day=1/part-r-00008.gz.parquet
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/parquet_partitioned/year=2015/
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/parquet_partitioned/year=2015/month=10/
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=25/
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=25/.part-r-00002.gz.parquet.crc
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=25/.part-r-00004.gz.parquet.crc
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=25/part-r-00002.gz.parquet
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=25/part-r-00004.gz.parquet
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=26/
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=26/.part-r-00005.gz.parquet.crc
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=26/part-r-00005.gz.parquet
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/parquet_partitioned/year=2015/month=9/
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/parquet_partitioned/year=2015/month=9/day=1/
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/parquet_partitioned/year=2015/month=9/day=1/.part-r-00007.gz.parquet.crc
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/parquet_partitioned/year=2015/month=9/day=1/part-r-00007.gz.parquet
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/people.json
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/people1.json
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/people_array.json
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/streaming/
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/streaming/text-test.txt
# spark-2.3.3-bin-hadoop2.6/python/test_support/sql/text-test.txt
# spark-2.3.3-bin-hadoop2.6/python/test_support/userlib-0.1.zip
# spark-2.3.3-bin-hadoop2.6/python/test_support/userlibrary.py
# spark-2.3.3-bin-hadoop2.6/R/
# spark-2.3.3-bin-hadoop2.6/R/lib/
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/DESCRIPTION
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/help/
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/help/aliases.rds
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/help/AnIndex
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/help/paths.rds
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/help/SparkR.rdb
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/help/SparkR.rdx
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/html/
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/html/00Index.html
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/html/R.css
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/INDEX
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/Meta/
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/Meta/features.rds
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/Meta/hsearch.rds
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/Meta/links.rds
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/Meta/nsInfo.rds
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/Meta/package.rds
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/Meta/Rd.rds
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/NAMESPACE
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/profile/
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/profile/general.R
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/profile/shell.R
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/R/
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/R/SparkR
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/R/SparkR.rdb
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/R/SparkR.rdx
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/tests/
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/tests/testthat/
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/tests/testthat/test_basic.R
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/worker/
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/worker/daemon.R
# spark-2.3.3-bin-hadoop2.6/R/lib/SparkR/worker/worker.R
# spark-2.3.3-bin-hadoop2.6/R/lib/sparkr.zip
# spark-2.3.3-bin-hadoop2.6/README.md
# spark-2.3.3-bin-hadoop2.6/RELEASE
# spark-2.3.3-bin-hadoop2.6/sbin/
# spark-2.3.3-bin-hadoop2.6/sbin/slaves.sh
# spark-2.3.3-bin-hadoop2.6/sbin/spark-config.sh
# spark-2.3.3-bin-hadoop2.6/sbin/spark-daemon.sh
# spark-2.3.3-bin-hadoop2.6/sbin/spark-daemons.sh
# spark-2.3.3-bin-hadoop2.6/sbin/start-all.sh
# spark-2.3.3-bin-hadoop2.6/sbin/start-history-server.sh
# spark-2.3.3-bin-hadoop2.6/sbin/start-master.sh
# spark-2.3.3-bin-hadoop2.6/sbin/start-mesos-dispatcher.sh
# spark-2.3.3-bin-hadoop2.6/sbin/start-mesos-shuffle-service.sh
# spark-2.3.3-bin-hadoop2.6/sbin/start-shuffle-service.sh
# spark-2.3.3-bin-hadoop2.6/sbin/start-slave.sh
# spark-2.3.3-bin-hadoop2.6/sbin/start-slaves.sh
# spark-2.3.3-bin-hadoop2.6/sbin/start-thriftserver.sh
# spark-2.3.3-bin-hadoop2.6/sbin/stop-all.sh
# spark-2.3.3-bin-hadoop2.6/sbin/stop-history-server.sh
# spark-2.3.3-bin-hadoop2.6/sbin/stop-master.sh
# spark-2.3.3-bin-hadoop2.6/sbin/stop-mesos-dispatcher.sh
# spark-2.3.3-bin-hadoop2.6/sbin/stop-mesos-shuffle-service.sh
# spark-2.3.3-bin-hadoop2.6/sbin/stop-shuffle-service.sh
# spark-2.3.3-bin-hadoop2.6/sbin/stop-slave.sh
# spark-2.3.3-bin-hadoop2.6/sbin/stop-slaves.sh
# spark-2.3.3-bin-hadoop2.6/sbin/stop-thriftserver.sh
# spark-2.3.3-bin-hadoop2.6/yarn/
# spark-2.3.3-bin-hadoop2.6/yarn/spark-2.3.3-yarn-shuffle.jar

# %%
# !pip install findspark
# !pip install systemml
# Out:
# Collecting findspark
#   Downloading https://files.pythonhosted.org/packages/b1/c8/e6e1f6a303ae5122dc28d131b5a67c5eb87cbf8f7ac5b9f87764ea1b1e1e/findspark-1.3.0-py2.py3-none-any.whl
# Installing collected packages: findspark
# Successfully installed findspark-1.3.0
# Collecting systemml
#   Downloading https://files.pythonhosted.org/packages/b1/94/62104cb8c526b462cd501c7319926fb81ac9a5668574a0b3407658a506ab/systemml-1.2.0.tar.gz (9.7MB)
#      |████████████████████████████████| 9.7MB 3.8MB/s
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python2.7/dist-packages (from systemml) (1.16.4)
# Requirement already satisfied: scipy>=0.15.1 in /usr/local/lib/python2.7/dist-packages (from systemml) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python2.7/dist-packages (from systemml) (0.24.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python2.7/dist-packages (from systemml) (0.20.3)
# Requirement already satisfied: Pillow>=2.0.0 in /usr/local/lib/python2.7/dist-packages (from systemml) (4.3.0)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python2.7/dist-packages (from pandas->systemml) (2018.9)
# Requirement already satisfied: python-dateutil>=2.5.0 in /usr/local/lib/python2.7/dist-packages (from pandas->systemml) (2.5.3)
# Requirement already satisfied: olefile in /usr/local/lib/python2.7/dist-packages (from Pillow>=2.0.0->systemml) (0.46)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python2.7/dist-packages (from python-dateutil>=2.5.0->pandas->systemml) (1.12.0)
# Building wheels for collected packages: systemml
#   Building wheel for systemml (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/cf/07/79/b3ed6f12afe06b2ab55d60dcfd62e66240f5d8c6088a518177
# Successfully built systemml
# Installing collected packages: systemml
# Successfully installed systemml-1.2.0

# %%
import os 
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-2.3.3-bin-hadoop2.6"

# %%
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()

# %%
df = spark.createDataFrame([{"hello":"world"} for x in range(1000)])
df.show(1)
# Out:
# +-----+
# |hello|
# +-----+
# |world|
# +-----+
# only showing top 1 row

# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
import keras
import tensorflow as tf

from keras.layers import Flatten, Dense, Dropout, BatchNormalization
from keras.optimizers import Adam

# %%
# !pip install gdown
import gdown

#gdown.download("https://drive.google.com/uc?id={0}".format("1c-p-K9vG5Ijh8A6anvUpwuf21eClvV99"),"gt.pickle",quiet= False)
#gdown.download("https://drive.google.com/uc?id={0}".format("1lCgm8ooBaTeLYI_9Q13015BgrVDY0FPy"),"occ.pickle",quiet= False)
gdown.download("https://drive.google.com/uc?id={0}".format("1lCgm8ooBaTeLYI_9Ql30l5BgrVDY0FPy"),"occ.pickle",quiet = False)
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python2.7/dist-packages (3.6.4)
# Requirement already satisfied: six in /usr/local/lib/python2.7/dist-packages (from gdown) (1.12.0)
# Requirement already satisfied: requests in /usr/local/lib/python2.7/dist-packages (from gdown) (2.21.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python2.7/dist-packages (from gdown) (4.28.1)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python2.7/dist-packages (from requests->gdown) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python2.7/dist-packages (from requests->gdown) (2019.6.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python2.7/dist-packages (from requests->gdown) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python2.7/dist-packages (from requests->gdown) (2.8)
# Downloading...
# From: https://drive.google.com/uc?id=1lCgm8ooBaTeLYI_9Ql30l5BgrVDY0FPy
# To: /content/occ.pickle
# 221MB [00:04, 49.6MB/s]
# 'occ.pickle'

# %%
import io 
with open("occ.pickle","rb") as pickle_dosyam:
  x = pickle.load(pickle_dosyam)

y = x

# %%
from skimage.transform import resize

x = resize(x, (len(x),64,64,1),anti_aliasing=False)

y= resize(y, (len(y),64,64,1),anti_aliasing=False)

# %%
fig = plt.figure(figsize = (6,6))

fig.add_subplot(1,2,1)

plt.imshow(x[10,:,:,0], cmap = "gray")

fig.add_subplot(1,2,2)

plt.imshow(y[10,:,:,0], cmap = "gray")

# %%
from keras.models import Sequential

modelim = Sequential()
modelim.add(Dense(16, input_shape = [64*64], activation = "relu"))
modelim.add(BatchNormalization())
modelim.add(Dropout(0.3))

modelim.add(Dense(64*64, activation = "relu"))
modelim.add(BatchNormalization())
modelim.add(Dropout(0.3))

modelim.compile(loss = "mean_squared_error", optimizer = "adam")
modelim.summary()
# Out:
# W0720 09:18:18.814608 140719706417024 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0720 09:18:18.850197 140719706417024 deprecation.py:506] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 16)                65552
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16)                64
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4096)              69632
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 4096)              16384
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4096)              0
# =================================================================
# Total params: 151,632
# Trainable params: 143,408
# Non-trainable params: 8,224
# _________________________________________________________________

# %%
from systemml.mllearn import Keras2DML
import math

epochs = 50
batch_size = 50
samples = 3000
max_iter = int(epochs*math.ceil(samples/batch_size))

modelim = Keras2DML(spark, modelim, input_shape=[64,64,1], batch_size= batch_size, max_iter=max_iter)

modelim.set(debug=True)
# Out:
# Loading the model from /tmp/tmpskXVpT...
# SystemML Statistics:
# Total execution time:		0.000 sec.
# Number of executed Spark inst:	0.
# Caffe2DML

# %%
modelim.fit(x.reshape((4471,4096)),x.reshape((4471,4096)))
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/systemml/mllearn/estimators.py", line 176, in _fit_numpy
#     self.model = self.estimator.fit(convertToMatrixBlock(self.sc, self.X), y_mb)
#   File "/content/spark-2.3.3-bin-hadoop2.6/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1257, in __call__
#     answer, self.gateway_client, self.target_id, self.name)
#   File "/content/spark-2.3.3-bin-hadoop2.6/python/pyspark/sql/utils.py", line 63, in deco
#     return f(*a, **kw)
#   File "/content/spark-2.3.3-bin-hadoop2.6/python/lib/py4j-0.10.7-src.zip/py4j/protocol.py", line 328, in get_return_value
#     format(target_id, ".", name), value)
# Py4JJavaError: An error occurred while calling o186.fit.
# : org.apache.sysml.parser.LanguageException: Layer with name dense_2_input not found
# 	at org.apache.sysml.api.dl.CaffeNetwork.throwException(CaffeNetwork.scala:208)
# 	at org.apache.sysml.api.dl.CaffeNetwork.getCaffeLayer(CaffeNetwork.scala:215)
# 	at org.apache.sysml.api.dl.CaffeLayer$$anonfun$1.apply(CaffeLayer.scala:54)
# 	at org.apache.sysml.api.dl.CaffeLayer$$anonfun$1.apply(CaffeLayer.scala:54)
# 	at scala.collection.TraversableLike$$anonfun$map$1.apply(TraversableLike.scala:234)
# 	at scala.collection.TraversableLike$$anonfun$map$1.apply(TraversableLike.scala:234)
# 	at scala.collection.immutable.Set$Set1.foreach(Set.scala:94)
# 	at scala.collection.TraversableLike$class.map(TraversableLike.scala:234)
# 	at scala.collection.AbstractSet.scala$collection$SetLike$$super$map(Set.scala:47)
# 	at scala.collection.SetLike$class.map(SetLike.scala:92)
# 	at scala.collection.AbstractSet.map(Set.scala:47)
# 	at org.apache.sysml.api.dl.CaffeLayer$class.bottomLayerOutputShape(CaffeLayer.scala:54)
# 	at org.apache.sysml.api.dl.InnerProduct.bottomLayerOutputShape(CaffeLayer.scala:842)
# 	at org.apache.sysml.api.dl.InnerProduct.numFeatures(CaffeLayer.scala:915)
# 	at org.apache.sysml.api.dl.InnerProduct.init(CaffeLayer.scala:869)
# 	at org.apache.sysml.api.dl.DMLGenerator$$anonfun$initWeights$1.apply(DMLGenerator.scala:326)
# 	at org.apache.sysml.api.dl.DMLGenerator$$anonfun$initWeights$1.apply(DMLGenerator.scala:326)
# 	at scala.collection.immutable.List.map(List.scala:273)
# 	at org.apache.sysml.api.dl.DMLGenerator$class.initWeights(DMLGenerator.scala:326)
# 	at org.apache.sysml.api.dl.Caffe2DML.initWeights(Caffe2DML.scala:164)
# 	at org.apache.sysml.api.dl.Caffe2DML.getTrainingScript(Caffe2DML.scala:322)
# 	at org.apache.sysml.api.ml.BaseSystemMLClassifier$class.baseFit(BaseSystemMLClassifier.scala:238)
# 	at org.apache.sysml.api.dl.Caffe2DML.baseFit(Caffe2DML.scala:164)
# 	at org.apache.sysml.api.dl.Caffe2DML.fit(Caffe2DML.scala:215)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:238)
# 	at java.lang.Thread.run(Thread.java:748)
# Caffe2DML
